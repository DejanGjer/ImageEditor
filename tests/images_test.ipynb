# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
filepath = '../image_effects_backend/api/static/img/np_saved.npy'

# Load the data
data = np.load(filepath)
print(data.shape)
print(data.dtype)
# Out:
# (480, 640, 3)
# uint8

# %%
# show data as image with matplotlib
plt.imshow(data)
plt.show()

# %%
print(data[50, 400, :])
# Out:
# [232 222 172]
